# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav4518/Abhinav4518/blob/main/TF2_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,10*np.pi,100)
y=np.sin(x)

# %%
plt.plot(x,y)
