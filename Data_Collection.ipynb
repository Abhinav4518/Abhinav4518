# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav4518/Abhinav4518/blob/main/Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Collection Sites:
# 1.Kaggle
# 2.UCI Machine Learning Repo
# 3.Google Dataset search

# %%
import pandas as pd

# %%
#loading a dataset to a pandas dataframe
dataset=pd.read_csv('/content/boston.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  PRICE
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2

# %% [markdown]
# #API-Application Programming Interface

# %%
#Installing the kaggle library
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2c17ee8e-9b9f-42ff-ba64-791ffaf23c99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c17ee8e-9b9f-42ff-ba64-791ffaf23c99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.rename("kaggle(1).json", "kaggle.json")

# %% [markdown]
# Upload your kaggle.json file

# %%
#Configuring the path of kaggle.json
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing the Earthquake Dataset

# %%
#API to fetch the dataset from Kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
#  99% 2.26G/2.27G [00:18<00:00, 266MB/s]
# 100% 2.27G/2.27G [00:18<00:00, 134MB/s]

# %%
#extraxting the compressed dataset
from zipfile import ZipFile
dataset='/content/LANL-Earthquake-Prediction.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted
